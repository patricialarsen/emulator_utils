# %%
import numpy as np
import matplotlib.pylab as plt

# %%
fileIn = '../../emulator_utils/test/data/dc2_igr/irg.npy'

# %%
igr = np.load(fileIn)
print(igr.shape)
# Out:
# (3, 300, 300)

# %%
plt.figure(12)
plt.imshow(np.array(igr).transpose(), origin='lower')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from emulator_utils import pre_process2d

# %%
norm_mat = np.array(pre_process2d.norm2d( np.array(igr)/255. ))

plt.figure(12)
plt.imshow(norm_mat.astype(np.uint8), origin='lower')
