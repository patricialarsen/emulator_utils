# %%
import numpy as np
import matplotlib.pylab as plt

# %%
fileIn = '/lcrc/project/cosmo_ai/nramachandra/Projects/Ulab_ldrd/emulator_utils/test/data/dc2_igr/irg.npy'

# %%
igr = np.load(fileIn)
print(igr.shape)
# Out:
# (3, 300, 300)

# %%
plt.imshow(igr.T)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
